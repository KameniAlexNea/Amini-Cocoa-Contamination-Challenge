# %%
# create a user object
from zindi.user import Zindian

my_username = "Kamenialexnea"
user = Zindian(username = my_username)
# Out:
# [ 🟢 ] 👋🏾👋🏾 Welcome Kamenialexnea 👋🏾👋🏾

# %%
user.select_a_challenge()
# Out:
# __________________________________________________________________________________________________________________________________
# |     |              |                  |                    |
# |index|  challenge   |     problem      |       reward       |    id
# |     |              |                  |                    |
# ----------------------------------------------------------------------------------------------------------------------------------
# |  0  |Public Compet |    Prediction    |     $3 000 USD     | ibm-skillsbuild-hydropower-climate-optimisation-ch...
# ----------------------------------------------------------------------------------------------------------------------------------
# |  1  |Public Compet | Computer Vision  |     $7 000 USD     | amini-cocoa-contamination-challenge...
# ----------------------------------------------------------------------------------------------------------------------------------
# |  2  |Public Compet |Natural Language P|     $1 300 USD     | lelapa-ai-buzuzu-mavi-challenge...
# ----------------------------------------------------------------------------------------------------------------------------------
# |  3  |Public Compet |    Prediction    |    3 000 Points    | international-womens-day-challenge...
# ----------------------------------------------------------------------------------------------------------------------------------
# |  4  |Public Compet |  Classification  |    3 000 Points    | amini-canopy-or-crop-challenge...
# ----------------------------------------------------------------------------------------------------------------------------------
# |  5  |Public Compet |    Prediction    |     20 000 CHF     | aiml-for-5g-energy-consumption-modelling...
# ----------------------------------------------------------------------------------------------------------------------------------
# |  6  |Public Compet |    Prediction    |     18 000 CHF     | smart-energy-supply-scheduling-for-green-telecom...
# ----------------------------------------------------------------------------------------------------------------------------------
# |  7  |Public Compet |     Forecast     |    $17 000 USD     | rmb-cpi-nowcasting-challenge...
# ----------------------------------------------------------------------------------------------------------------------------------
# |  8  |Public Compet | Computer Vision  |    $15 000 USD     | cgiar-root-volume-estimation-challenge...
# ----------------------------------------------------------------------------------------------------------------------------------
# |  9  |Public Compet | Object Detection |    €15 000 EUR     | wadhwani-ai-bollworm-counting-challenge...
# ----------------------------------------------------------------------------------------------------------------------------------
# | 10  |Public Compet |     Forecast     |     12 000 CHF     | spatio-temporal-beam-level-traffic-forecasting-cha...
# ----------------------------------------------------------------------------------------------------------------------------------
# | 11  |Public Compet |    Prediction    |    $12 000 USD     | traffic-jam-predicting-peoples-movement-into-nairo...
# ----------------------------------------------------------------------------------------------------------------------------------
# | 12  |Public Compet |  Classification  |    $11 000 USD     | farm-pin-crop-detection-challenge...
# ----------------------------------------------------------------------------------------------------------------------------------
# | 13  |Public Compet |  Classification  |    $10 000 USD     | inundata-mapping-floods-in-south-africa...
# ----------------------------------------------------------------------------------------------------------------------------------
# | 14  |Public Compet |    Collection    |    $10 000 USD     | amini-crop-data-citizen-science-challenge...
# ----------------------------------------------------------------------------------------------------------------------------------
# | 15  |Public Compet |    Blockchain    |    $10 000 USD     | itu-digital-financial-services-blockchain-secure-a...
# ----------------------------------------------------------------------------------------------------------------------------------
# | 16  |Public Compet |    Prediction    |    $10 000 USD     | arm-unicef-disaster-vulnerability-challenge...
# ----------------------------------------------------------------------------------------------------------------------------------
# | 17  |Public Compet |  Classification  |    $10 000 USD     | cgiar-crop-damage-classification-challenge...
# ----------------------------------------------------------------------------------------------------------------------------------
# | 18  |Public Compet |    Prediction    |    $10 000 USD     | cgiar-eyes-on-the-ground-challenge...
# ----------------------------------------------------------------------------------------------------------------------------------
# | 19  |Public Compet |    Prediction    |    $10 000 USD     | digital-africa-plantation-counting-challenge...
# ----------------------------------------------------------------------------------------------------------------------------------
# | 20  |Public Compet |Earth Observation |    $10 000 USD     | africa-biomass-challenge...
# ----------------------------------------------------------------------------------------------------------------------------------
# | 21  |Public Compet |  Classification  |    $10 000 USD     | agrifieldnet-india-challenge...
# ----------------------------------------------------------------------------------------------------------------------------------
# | 22  |Public Compet |  Classification  |    $10 000 USD     | turtle-recall-conservation-challenge...
# ----------------------------------------------------------------------------------------------------------------------------------
# | 23  |Public Compet |    Prediction    |    $10 000 USD     | lacuna-correct-field-detection-challenge...
# ----------------------------------------------------------------------------------------------------------------------------------
# | 24  |Public Compet |     Forecast     |    $10 000 USD     | 2030-vision-flood-prediction-in-malawi...
# ----------------------------------------------------------------------------------------------------------------------------------
# | 25  |Public Compet |  Classification  |     $8 800 USD     | radiant-earth-spot-the-crop-xl-challenge...
# ----------------------------------------------------------------------------------------------------------------------------------
# | 26  |Public Compet |  Classification  |     $8 800USD      | radiant-earth-spot-the-crop-challenge...
# ----------------------------------------------------------------------------------------------------------------------------------
# | 27  |Public Compet | Computer Vision  |     $8 000 USD     | ghana-crop-disease-detection-challenge...
# ----------------------------------------------------------------------------------------------------------------------------------
# | 28  |Public Compet |  Classification  |     8 000 CHF      | fault-impact-analysis-towards-service-oriented-net...
# ----------------------------------------------------------------------------------------------------------------------------------
# | 29  |Public Compet |     Forecast     |     $8 000 USD     | wazihub-soil-moisture-prediction-challenge...
# ----------------------------------------------------------------------------------------------------------------------------------
# | 30  |Public Compet |    Prediction    |     $7 500 USD     | hulkshare-recommendation-algorithm-challenge...
# ----------------------------------------------------------------------------------------------------------------------------------
# | 31  |Public Compet |  Classification  |     $7 500 USD     | bloodsai-blood-spectroscopy-classification-challen...
# ----------------------------------------------------------------------------------------------------------------------------------
# | 32  |Public Compet | Object Detection |$12 500 USD + AWS cr| kuyesera-ai-disaster-damage-and-displacement-chall...
# ----------------------------------------------------------------------------------------------------------------------------------
# | 33  |Public Compet |    Prediction    |$12 500 USD + AWS cr| outsmarting-outbreaks-challenge...
# ----------------------------------------------------------------------------------------------------------------------------------
# | 34  |Public Compet |  Classification  |     €6 900 EUR     | telangana-crop-health-challenge...
# ----------------------------------------------------------------------------------------------------------------------------------
# | 35  |Public Compet |  Classification  |     $7 000 USD     | lacuna-masakhane-parts-of-speech-classification-ch...
# ----------------------------------------------------------------------------------------------------------------------------------
# | 36  |Public Compet |  Classification  |     $7 000 USD     | giz-nlp-agricultural-keyword-spotter...
# ----------------------------------------------------------------------------------------------------------------------------------
# | 37  |Public Compet |    Prediction    |     $7 000 USD     | sendy-logistics-challenge...
# ----------------------------------------------------------------------------------------------------------------------------------
# | 38  |Public Compet |      MLOps       |     $6 500 USD     | melio-mlops-competition...
# ----------------------------------------------------------------------------------------------------------------------------------
# | 39  |Public Compet |    Prediction    |     $6 000 USD     | uber-nairobi-ambulance-perambulation-challenge...
# ----------------------------------------------------------------------------------------------------------------------------------
# | 40  |Public Compet |    Collection    |     $6 000 USD     | ai4d-african-language-dataset-challenge...
# ----------------------------------------------------------------------------------------------------------------------------------
# | 41  |Public Compet |    Prediction    |     $5 500 USD     | uber-movement-sanral-cape-town-challenge...
# ----------------------------------------------------------------------------------------------------------------------------------
# | 42  |Public Compet |    Prediction    |     $5 000 USD     | zindi-new-user-engagement-prediction-challenge...
# ----------------------------------------------------------------------------------------------------------------------------------
# | 43  |Public Compet | Computer Vision  |     $5 000 USD     | lacuna-solar-survey-challenge...
# ----------------------------------------------------------------------------------------------------------------------------------
# | 44  |Public Compet |  Classification  |     $5 000 USD     | african-credit-scoring-challenge...
# ----------------------------------------------------------------------------------------------------------------------------------
# | 45  |Public Compet |  Classification  |     $1 000 USD     | techcabal-ewe-audio-translation-challenge...
# ----------------------------------------------------------------------------------------------------------------------------------
# | 46  |Public Compet | Object Detection |     $5 000 USD     | lacuna-malaria-detection-challenge...
# ----------------------------------------------------------------------------------------------------------------------------------
# | 47  |Public Compet |  Generative AI   |     $1 500 USD     | retrieval-augmented-generation-rag-for-public-serv...
# ----------------------------------------------------------------------------------------------------------------------------------
# | 48  |Public Compet |Natural Language P|     $5 000 USD     | microsoft-learn-location-mention-recognition-chall...
# ----------------------------------------------------------------------------------------------------------------------------------
# | 49  |Public Compet |  Generative AI   |     €6 000 EUR     | specializing-large-language-models-for-telecom-net...
# ----------------------------------------------------------------------------------------------------------------------------------
# | 50  |Public Compet |Questioning and An|     $2 000 USD     | malawi-public-health-systems-llm-challenge...
# ----------------------------------------------------------------------------------------------------------------------------------
# | 51  |Public Compet |    Prediction    |     €9 400 EUR     | digital-green-crop-yield-estimate-challenge...
# ----------------------------------------------------------------------------------------------------------------------------------
# | 52  |Public Compet |    Prediction    |     $5 000 USD     | multi-machine-disruption-prediction-challenge...
# ----------------------------------------------------------------------------------------------------------------------------------
# | 53  |Public Compet |Automatic Speech R|     $5 000 USD     | intron-afrispeech-200-automatic-speech-recognition...
# ----------------------------------------------------------------------------------------------------------------------------------
# | 54  |Public Compet |    Prediction    |     $5 000 USD     | absa-customer-income-prediction-challenge...
# ----------------------------------------------------------------------------------------------------------------------------------
# | 55  |Public Compet |  Classification  |     $5 000 USD     | nasa-harvest-field-boundary-detection-challenge...
# ----------------------------------------------------------------------------------------------------------------------------------
# | 56  |Public Compet |     Forecast     |     $5 000 USD     | absa-corporate-client-activity-forecasting-challen...
# ----------------------------------------------------------------------------------------------------------------------------------
# | 57  |Public Compet |     Forecast     |     $5 000 USD     | fossil-stock-forecasting-challenge...
# ----------------------------------------------------------------------------------------------------------------------------------
# | 58  |Public Compet |  Generative AI   |     $5 000 USD     | unifi-value-frameworks-pdf-lifting-competition...
# ----------------------------------------------------------------------------------------------------------------------------------
# | 59  |Public Compet |  Classification  |     $5 000 USD     | kenyan-sign-language-classification-challenge...
# ----------------------------------------------------------------------------------------------------------------------------------
# | 60  |Public Compet |    Prediction    |     $5 000 USD     | sfc-paygo-solar-credit-repayment-competition...
# ----------------------------------------------------------------------------------------------------------------------------------
# | 61  |Public Compet |  Visualisation   |     $5 000 USD     | afd-solutions-for-gender-based-violence-challenge...
# ----------------------------------------------------------------------------------------------------------------------------------
# | 62  |Public Compet |    Prediction    |     $5 000 USD     | zimnat-insurance-recommendation-challenge...
# ----------------------------------------------------------------------------------------------------------------------------------
# | 63  |Public Compet |     Forecast     |     $5 000 USD     | airqo-ugandan-air-quality-forecast-challenge...
# ----------------------------------------------------------------------------------------------------------------------------------
# | 64  |Public Compet |     Forecast     |     $5 000 USD     | predict-the-global-spread-of-covid-19...
# ----------------------------------------------------------------------------------------------------------------------------------
# | 65  |Public Compet |  Classification  |     $5 000 USD     | iclr-workshop-challenge-2-radiant-earth-computer-v...
# ----------------------------------------------------------------------------------------------------------------------------------
# | 66  |Public Compet |  Classification  |     $5 000 USD     | iclr-workshop-challenge-1-cgiar-computer-vision-fo...
# ----------------------------------------------------------------------------------------------------------------------------------
# | 67  |Public Compet |  Visualisation   |     $5 000 USD     | 2030-vision-data-visualization-and-reporting-chall...
# ----------------------------------------------------------------------------------------------------------------------------------
# | 68  |Public Compet |    Prediction    |     $5 000 USD     | womxn-in-big-data-south-africa-female-headed-house...
# ----------------------------------------------------------------------------------------------------------------------------------
# | 69  |Public Compet |  Classification  |     $4 500 USD     | xente-fraud-detection-challenge...
# ----------------------------------------------------------------------------------------------------------------------------------
# | 70  |Public Compet |  Classification  |     $4 200 USD     | basic-needs-basic-rights-kenya-tech4mentalhealth...
# ----------------------------------------------------------------------------------------------------------------------------------
# | 71  |Public Compet |  Classification  |     $4 000 USD     | geo-ai-challenge-for-cropland-mapping-with-satelli...
# ----------------------------------------------------------------------------------------------------------------------------------
# | 72  |Public Compet |    Collection    |     $3 500 USD     | giz-kinyarwanda-text-cleaning-and-augmentation-com...
# ----------------------------------------------------------------------------------------------------------------------------------
# | 73  |Public Compet |     Forecast     | 3 000 Zindi Points | olympic-2024-medal-prediction-challenge...
# ----------------------------------------------------------------------------------------------------------------------------------
# | 74  |Public Compet |  Classification  |     1 000 CHF      | inegi-gcim-human-settlement-detection-challenge...
# ----------------------------------------------------------------------------------------------------------------------------------
# | 75  |Public Compet |  Classification  |     1 000 CHF      | inegi-gcim-vegetation-mapping-challenge...
# ----------------------------------------------------------------------------------------------------------------------------------
# | 76  |Public Compet |  Classification  |     2 000 CHF      | geoai-amazon-basin-secret-runway-detection-challen...
# ----------------------------------------------------------------------------------------------------------------------------------
# | 77  |Public Compet |  Remote Sensing  |     1 000 CHF      | geoai-challenge-for-agricultural-plastic-cover-map...
# ----------------------------------------------------------------------------------------------------------------------------------
# | 78  |Public Compet |    Prediction    |     1 000 CHF      | geoai-ground-level-no2-estimation-challenge...
# ----------------------------------------------------------------------------------------------------------------------------------
# | 79  |Public Compet |    Prediction    |3,000,000 XOF to be | togo-fiber-optics-uptake-prediction-challenge...
# ----------------------------------------------------------------------------------------------------------------------------------
# | 80  |Public Compet |     Forecast     |      $500 USD      | adbot-ad-engagement-forecasting-challenge...
# ----------------------------------------------------------------------------------------------------------------------------------
# | 81  |Public Compet |    Prediction    |     $3 000 USD     | airqo-african-air-quality-prediction-challenge...
# ----------------------------------------------------------------------------------------------------------------------------------
# | 82  |Public Compet |    Prediction    |    R10 000 ZAR     | sasol-customer-retention-recruitment-competition...
# ----------------------------------------------------------------------------------------------------------------------------------
# | 83  |Public Compet |    Prediction    |     $1 000 USD     | geoai-challenge-estimating-soil-parameters-from-hy...
# ----------------------------------------------------------------------------------------------------------------------------------
# | 84  |Public Compet |Automatic Speech R|     $1 000 USD     | ai4d-africas-anglophone-research-lab-tanzania-auto...
# ----------------------------------------------------------------------------------------------------------------------------------
# | 85  |Public Compet |    Prediction    |     $1 000 USD     | network-traffic-scenario-prediction-challenge...
# ----------------------------------------------------------------------------------------------------------------------------------
# | 86  |Public Compet |     Forecast     |     $1 000 USD     | geoai-challenge-for-air-pollution-susceptibility-m...
# ----------------------------------------------------------------------------------------------------------------------------------
# | 87  |Public Compet |    Prediction    |     1 000 CHF      | geoai-challege-location-mention-recognition-from-s...
# ----------------------------------------------------------------------------------------------------------------------------------
# | 88  |Public Compet |  Classification  |     $1 000 USD     | geo-ai-challenge-for-landslide-susceptibility-mapp...
# ----------------------------------------------------------------------------------------------------------------------------------
# | 89  |Public Compet |    Prediction    |    R10 000 ZAR     | predictive-insights-youth-income-prediction-challe...
# ----------------------------------------------------------------------------------------------------------------------------------
# | 90  |Public Compet |    Prediction    | 3 000 Zindi Points | qos-prediction-challenge...
# ----------------------------------------------------------------------------------------------------------------------------------
# | 91  |Public Compet | Computer Vision  | 3 000 Zindi Points | title-extraction-in-lecture-slides-challenge...
# ----------------------------------------------------------------------------------------------------------------------------------
# | 92  |Public Compet |    Prediction    |     $3 000 USD     | datadrive2030-early-learning-predictors-challenge...
# ----------------------------------------------------------------------------------------------------------------------------------
# | 93  |Public Compet |  Classification  | 3 000 Zindi Points | landslide-prevention-and-innovation-challenge...
# ----------------------------------------------------------------------------------------------------------------------------------
# | 94  |Public Compet |    Prediction    |     $3 000 USD     | layerai-air-quality-prediction-challenge...
# ----------------------------------------------------------------------------------------------------------------------------------
# | 95  |Public Compet |  Classification  |     $3 000 USD     | alvin-smart-money-management-classification-challe...
# ----------------------------------------------------------------------------------------------------------------------------------
# | 96  |Public Compet |  Classification  |     $3 000 USD     | microsoft-rice-disease-classification-challenge...
# ----------------------------------------------------------------------------------------------------------------------------------
# | 97  |Public Compet |Automatic Speech R|     $3 000 USD     | mozilla-luganda-automatic-speech-recognition...
# ----------------------------------------------------------------------------------------------------------------------------------
# | 98  |Public Compet |    Prediction    |     $3 000 USD     | zindi-user-behaviour-birthday-challenge...
# ----------------------------------------------------------------------------------------------------------------------------------
# | 99  |Public Compet |  Classification  |     $1 000 USD     | makerere-passion-fruit-disease-detection-challenge...
# ----------------------------------------------------------------------------------------------------------------------------------
# | 100 |Public Compet |    Prediction    |     $3 000 USD     | cgiar-crop-yield-prediction-challenge...
# ----------------------------------------------------------------------------------------------------------------------------------
# | 101 |Public Compet |  Classification  |     $3 000 USD     | cgiar-wheat-growth-stage-challenge...
# ----------------------------------------------------------------------------------------------------------------------------------
# | 102 |Public Compet |Reinforcement Lear| 3000 Zindi Points  | indaba-grand-challenge-curing-leishmaniasis...
# ----------------------------------------------------------------------------------------------------------------------------------
# | 103 |Public Compet |    Prediction    |     $3 000 USD     | akeed-restaurant-recommendation-challenge...
# ----------------------------------------------------------------------------------------------------------------------------------
# | 104 |Public Compet |  Visualisation   |     $3 195 USD     | animal-insights-challenge...
# ----------------------------------------------------------------------------------------------------------------------------------
# | 105 |Public Compet |    Prediction    | 2 000 Zindi Points | sbtic-xente-credit-scoring-challenge...
# ----------------------------------------------------------------------------------------------------------------------------------
# | 106 |Public Compet |  Visualisation   |     $3 000 USD     | ai-art...
# ----------------------------------------------------------------------------------------------------------------------------------
# | 107 |Public Compet |    Prediction    |     $1 000 USD     | autoinland-vehicle-insurance-claim-challenge...
# ----------------------------------------------------------------------------------------------------------------------------------
# | 108 |Public Compet |    Prediction    |     $2 250 USD     | mobile-money-and-financial-inclusion-in-tanzania-c...
# ----------------------------------------------------------------------------------------------------------------------------------
# | 109 |Public Compet |    Prediction    |    Get Started!    | predict-fire-extent...
# ----------------------------------------------------------------------------------------------------------------------------------
# | 110 |Public Compet |    Prediction    |     Qualifier      | total-energies-revolution-hackathon...
# ----------------------------------------------------------------------------------------------------------------------------------
# | 111 |Public Compet |    Prediction    |      $300 USD      | cains-jawbone-murder-mystery...
# ----------------------------------------------------------------------------------------------------------------------------------
# | 112 |Public Compet |    Prediction    |     $1 000 USD     | next-gen-wifi-throughput-prediction-challenge...
# ----------------------------------------------------------------------------------------------------------------------------------
# | 113 |Public Compet |  Visualisation   |     $2 000 USD     | zindi-design-your-profile-challenge...
# ----------------------------------------------------------------------------------------------------------------------------------
# | 114 |Public Compet |  Classification  |    2 000 Points    | swahili-audio-classification...
# ----------------------------------------------------------------------------------------------------------------------------------
# | 115 |Public Compet |  Classification  |     $1 000 USD     | datafest-africa-2022...
# ----------------------------------------------------------------------------------------------------------------------------------
# | 116 |Public Compet |    Prediction    |     $2 000 USD     | laduma-analytics-football-league-winners-predictio...
# ----------------------------------------------------------------------------------------------------------------------------------
# | 117 |Public Compet |  Classification  |     $1 000 USD     | expresso-churn-prediction...
# ----------------------------------------------------------------------------------------------------------------------------------
# | 118 |Public Compet |Natural Language P|    2000 Points     | gender-based-violence-tweet-classification-challen...
# ----------------------------------------------------------------------------------------------------------------------------------
# | 119 |Public Compet |    Prediction    |     $1 000 USD     | cryptocurrency-closing-price-prediction...
# ----------------------------------------------------------------------------------------------------------------------------------
# | 120 |Public Compet |    Prediction    |    2000 Points     | economic-well-being-prediction-challenge...
# ----------------------------------------------------------------------------------------------------------------------------------
# | 121 |Public Compet |  Classification  |     $2 000 USD     | ai4d-baamtu-datamation-automatic-speech-recognitio...
# ----------------------------------------------------------------------------------------------------------------------------------
# | 122 |Public Compet |  Classification  |     $2 000 USD     | ai4d-malawi-news-classification-challenge...
# ----------------------------------------------------------------------------------------------------------------------------------
# | 123 |Public Compet |Machine Translatio|     $2 000 USD     | ai4d-takwimu-lab-machine-translation-challenge...
# ----------------------------------------------------------------------------------------------------------------------------------
# | 124 |Public Compet |Machine Translatio|     $2 000 USD     | ai4d-yoruba-machine-translation-challenge...
# ----------------------------------------------------------------------------------------------------------------------------------
# | 125 |Public Compet |Natural Language P|     $2 000 USD     | ai4d-icompass-social-media-sentiment-analysis-for-...
# ----------------------------------------------------------------------------------------------------------------------------------
# | 126 |Public Compet |  Classification  |   Job Interview    | instadeep-enzyme-classification-challenge...
# ----------------------------------------------------------------------------------------------------------------------------------
# | 127 |Public Compet |  Classification  | 2000 Zindi Points  | runmila-ai-institute-minohealth-ai-labs-tuberculos...
# ----------------------------------------------------------------------------------------------------------------------------------
# | 128 |Public Compet |  Classification  | 2000 Zindi Points  | fowl-escapades...
# ----------------------------------------------------------------------------------------------------------------------------------
# | 129 |Public Compet |     Forecast     | 2000 Zindi Points  | sea-turtle-rescue-forecast-challenge...
# ----------------------------------------------------------------------------------------------------------------------------------
# | 130 |Public Compet |  Classification  | 2 000 Zindi Points | tic-heap-cirta-particle-classification-challenge...
# ----------------------------------------------------------------------------------------------------------------------------------
# | 131 |Public Compet |     Forecast     | 2000 Zindi Points  | mtoto-news-childline-kenya-call-volume-prediction-...
# ----------------------------------------------------------------------------------------------------------------------------------
# | 132 |Public Compet |  Classification  |     $1 950 USD     | sea-turtle-rescue-error-detection-challenge...
# ----------------------------------------------------------------------------------------------------------------------------------
# | 133 |Public Compet |  Visualisation   |     $1 500 USD     | deepfake-africa-challenge...
# ----------------------------------------------------------------------------------------------------------------------------------
# | 134 |Public Compet |    Prediction    | 1 000 Zindi Points | be-a-trailblazer-kenya...
# ----------------------------------------------------------------------------------------------------------------------------------
# | 135 |Public Compet |    Prediction    | 1 000 Zindi Points | be-a-trailblazer-south-africa...
# ----------------------------------------------------------------------------------------------------------------------------------
# | 136 |Public Compet |    Prediction    | 1 000 Zindi Points | be-a-trailblazer-open-to-all...
# ----------------------------------------------------------------------------------------------------------------------------------
# | 137 |Public Compet |    Prediction    | 1 000 Zindi Points | be-a-trailblazer-nigeria...
# ----------------------------------------------------------------------------------------------------------------------------------
# | 138 |Public Compet |  Classification  |     $1 000 USD     | ai4d-lab-tanzania-tourism-classification-challenge...
# ----------------------------------------------------------------------------------------------------------------------------------
# | 139 |Public Compet |  Classification  |     $1 000 USD     | makerere-fall-armyworm-crop-challenge...
# ----------------------------------------------------------------------------------------------------------------------------------
# | 140 |Public Compet |    Prediction    | 1 000 Zindi Points | be-a-trailblazer...
# ----------------------------------------------------------------------------------------------------------------------------------
# | 141 |Public Compet |    Prediction    |     $3 495 USD     | ix-mobile-banking-prediction-challenge...
# ----------------------------------------------------------------------------------------------------------------------------------
# | 142 |Public Compet |    Prediction    |     $1 000 USD     | airqo-low-cost-air-quality-monitor-calibration-cha...
# ----------------------------------------------------------------------------------------------------------------------------------
# | 143 |Public Compet |Natural Language P|     $1 000 USD     | sustainable-development-goals-sdgs-text-classifica...
# ----------------------------------------------------------------------------------------------------------------------------------
# | 144 |Public Compet |Natural Language P|     $1 000 USD     | social-media-prediction-challenge...
# ----------------------------------------------------------------------------------------------------------------------------------
# | 145 |Public Compet |     Forecast     |      $600 USD      | rmb-monthly-mini-challenge-5-nowcast-august...
# ----------------------------------------------------------------------------------------------------------------------------------
# | 146 |Public Compet |     Forecast     |      $600 USD      | rmb-monthly-mini-challenge-4-nowcast-july...
# ----------------------------------------------------------------------------------------------------------------------------------
# | 147 |Public Compet |     Forecast     |      $600 USD      | rmb-monthly-mini-challenge-3-nowcast-june...
# ----------------------------------------------------------------------------------------------------------------------------------
# | 148 |Public Compet |     Forecast     |      $600 USD      | rmb-monthly-mini-challenge-2-nowcast-may...
# ----------------------------------------------------------------------------------------------------------------------------------
# | 149 |Public Compet |     Forecast     |      $600 USD      | rmb-monthly-mini-challenge-1-nowcast-april...
# ----------------------------------------------------------------------------------------------------------------------------------
# | 150 |Public Compet |  Classification  |  500 Zindi Points  | bill-classification-in-tunisia-challenge...
# ----------------------------------------------------------------------------------------------------------------------------------
# | 151 |Public Compet |    Prediction    |  500 Zindi Points  | busara-mental-health-prediction-challenge...
# ----------------------------------------------------------------------------------------------------------------------------------
# | 152 |Public Compet |  Visualisation   |     $3 000 USD     | hack-the-continent-open-buildings-challenge...
# ----------------------------------------------------------------------------------------------------------------------------------
# | 153 |Public Compet |    Collection    |     $3 000 USD     | google-asr-hack-series-africa-asr-data-challenge...
# ----------------------------------------------------------------------------------------------------------------------------------
# | 154 |Public Compet |    Prediction    |    $10 000 USD     | total-energies-revolution-hackathon-finals...
# ----------------------------------------------------------------------------------------------------------------------------------
# | 155 |Public Compet |     Forecast     |     $5 000 USD     | fossil-top-5-challenge...
# ----------------------------------------------------------------------------------------------------------------------------------
# | 156 |Public Compet |    Prediction    |    Internships     | loan-default-prediction-challenge...
# ----------------------------------------------------------------------------------------------------------------------------------
# | 157 |Public Compet |    Collection    |     $1 000 USD     | afd-gender-based-violence-dataset-collection-chall...
# ----------------------------------------------------------------------------------------------------------------------------------
# | 158 |Public Compet |    Prediction    |    $25 000 USD     | usaids-intelligent-forecasting-challenge-model-fut...
# __________________________________________________________________________________________________________________________________
#
#
#
# [ 🟢 ] You choose the challenge : amini-cocoa-contamination-challenge,
# 	Can you develop a mobile-friendly machine learning model to identify diseases on cocoa leaves?.

# %%
user.which_challenge
# Out:
# [ 🟢 ] You are currently enrolled in : amini-cocoa-contamination-challenge challenge,
# 	Can you develop a mobile-friendly machine learning model to identify diseases on cocoa leaves?.
# 'amini-cocoa-contamination-challenge'

# %%
user.download_dataset(destination="./dataset")
# Out:
# ./dataset/SampleSubmission.csv: 67.2ko [00:00, 20.9Mo/s]
# ./dataset/Test.csv: 88.3ko [00:00, 5.56Mo/s]
# ./dataset/Train.csv: 843ko [00:00, 17.8Mo/s]
# ./dataset/dataset.zip: 100%|██████████| 9.43G/9.43G [05:03<00:00, 33.3Mo/s]
# ./dataset/Cocoa_Disease_Starter_Notebook.ipynb: 18.5Mo [00:00, 71.8Mo/s]
