# %%
import os
import pandas as pd
from glob import glob
from tqdm import tqdm

# %%
files = glob("zindi_challenge_cacao_tune/tuning_run/*/progress.csv")
len(files)
# Out:
# 150

# %%
example = pd.read_csv(files[0])
example
# Out:
#    metrics/precision(B)  metrics/recall(B)  metrics/mAP50(B)  \
# 0               0.00007            0.00901           0.00004
# 1               0.00000            0.00000           0.00000
# 2               0.14091            0.04306           0.03616
# 3               0.13229            0.28479           0.09078
# 4               0.11502            0.24724           0.07942
# 5               0.20368            0.31900           0.15447
# 6               0.17470            0.21184           0.14037
# 7               0.22852            0.32178           0.15935
# 8               0.22134            0.27334           0.16174
# 9               0.29903            0.28979           0.19486
#
#    metrics/mAP50-95(B)  val/box_loss  val/cls_loss  val/dfl_loss  epoch  \
# 0              0.00000           NaN           NaN           NaN      1
# 1              0.00000           NaN           NaN           NaN      2
# 2              0.01283           NaN           NaN           NaN      3
# 3              0.02947       6.51849       6.23603       2.80665      4
# 4              0.03691           NaN           NaN           NaN      5
# 5              0.06226       5.85929       4.64537       2.50205      6
# 6              0.05573       6.00468       4.80812       2.45678      7
# 7              0.06461       5.65962       4.56565       2.27737      8
# 8              0.06737       5.58609       4.46625       2.21835      9
# 9              0.07961       5.76080       4.36516       2.15988     10
#
#     timestamp  checkpoint_dir_name  ...  training_iteration     trial_id  \
# 0  1746148087                  NaN  ...                   1  4906f_00088
# 1  1746148145                  NaN  ...                   2  4906f_00088
# 2  1746148200                  NaN  ...                   3  4906f_00088
# 3  1746148238                  NaN  ...                   4  4906f_00088
# 4  1746148288                  NaN  ...                   5  4906f_00088
# 5  1746148330                  NaN  ...                   6  4906f_00088
# 6  1746148385                  NaN  ...                   7  4906f_00088
# 7  1746148440                  NaN  ...                   8  4906f_00088
# 8  1746148496                  NaN  ...                   9  4906f_00088
# 9  1746148552                  NaN  ...                  10  4906f_00088
#
#                   date time_this_iter_s  time_total_s     pid   hostname  \
# 0  2025-05-02_01-08-07        87.520509     87.520509  696205  frapai16p
# 1  2025-05-02_01-09-05        55.953616    143.474125  696205  frapai16p
# 2  2025-05-02_01-10-00        54.375264    197.849390  696205  frapai16p
# 3  2025-05-02_01-10-38        38.375390    236.224780  696205  frapai16p
# 4  2025-05-02_01-11-28        49.879291    286.104071  696205  frapai16p
# 5  2025-05-02_01-12-10        42.273691    328.377762  696205  frapai16p
# 6  2025-05-02_01-13-05        54.405740    382.783502  696205  frapai16p
# 7  2025-05-02_01-14-00        55.670712    438.454214  696205  frapai16p
# 8  2025-05-02_01-14-56        55.665905    494.120119  696205  frapai16p
# 9  2025-05-02_01-15-52        55.573338    549.693457  696205  frapai16p
#
#          node_ip time_since_restore  iterations_since_restore
# 0  192.168.16.12          87.520509                         1
# 1  192.168.16.12         143.474125                         2
# 2  192.168.16.12         197.849390                         3
# 3  192.168.16.12         236.224780                         4
# 4  192.168.16.12         286.104071                         5
# 5  192.168.16.12         328.377762                         6
# 6  192.168.16.12         382.783502                         7
# 7  192.168.16.12         438.454214                         8
# 8  192.168.16.12         494.120119                         9
# 9  192.168.16.12         549.693457                        10
#
# [10 rows x 21 columns]

# %%
example.columns
# Out:
# Index(['metrics/precision(B)', 'metrics/recall(B)', 'metrics/mAP50(B)',
#        'metrics/mAP50-95(B)', 'val/box_loss', 'val/cls_loss', 'val/dfl_loss',
#        'epoch', 'timestamp', 'checkpoint_dir_name', 'done',
#        'training_iteration', 'trial_id', 'date', 'time_this_iter_s',
#        'time_total_s', 'pid', 'hostname', 'node_ip', 'time_since_restore',
#        'iterations_since_restore'],
#       dtype='object')

# %%
# Load all CSV files into a single DataFrame
all_data = pd.concat([pd.read_csv(file).tail(1) for file in files], ignore_index=True)

# Filter the DataFrame to include only the specified columns
columns_of_interest = [
    "metrics/precision(B)",
    "metrics/recall(B)",
    "metrics/mAP50(B)",
    "metrics/mAP50-95(B)",
    "val/box_loss",
    "val/cls_loss",
    "val/dfl_loss",
    "epoch",
    "timestamp",
    "checkpoint_dir_name",
    "done",
    "training_iteration",
    "trial_id",
    "date",
    "time_this_iter_s",
    "time_total_s",
    "pid",
    "hostname",
    "node_ip",
    "time_since_restore",
    "iterations_since_restore",
]
filtered_data = all_data[columns_of_interest]

# Sort the DataFrame to find the top 10 experiments based on 'metrics/mAP50(B)'
top_10_experiments = filtered_data.sort_values(
    by=[
        "metrics/mAP50-95(B)",
        "metrics/mAP50(B)",
        "val/box_loss",
        "val/cls_loss",
        "val/dfl_loss",
    ],
    ascending=False,
).head(15)

top_10_experiments
# Out:
#      metrics/precision(B)  metrics/recall(B)  metrics/mAP50(B)  \
# 106               0.79764            0.48442           0.59333
# 111               0.81120            0.45739           0.58416
# 82                0.54076            0.46651           0.49341
# 1                 0.65474            0.48990           0.54699
# 76                0.62881            0.44398           0.42962
# 74                0.62689            0.41125           0.48583
# 33                0.68591            0.41288           0.44390
# 103               0.52825            0.47523           0.42275
# 138               0.59751            0.42737           0.46584
# 35                0.48080            0.42241           0.41864
# 4                 0.62322            0.37530           0.39805
# 133               0.54294            0.43442           0.43803
# 3                 0.65581            0.41929           0.39914
# 97                0.51144            0.37934           0.37151
# 49                0.44321            0.39702           0.39995
#
#      metrics/mAP50-95(B)  val/box_loss  val/cls_loss  val/dfl_loss  epoch  \
# 106              0.37920       3.24221      10.72639       1.68175     12
# 111              0.33471       2.45463       7.83894       3.39335     12
# 82               0.30038       3.35695       7.66204       3.11183     12
# 1                0.27292       2.22462      12.05279       0.97501     12
# 76               0.27094       2.25988       6.37747       3.30324     12
# 74               0.25682       2.66017      15.88735       4.44508     12
# 33               0.25484       2.14887       8.02815       1.70921     12
# 103              0.23755       4.58989      10.22691       2.86648     12
# 138              0.23621       1.73008       7.84999       3.69570     12
# 35               0.22603       1.24219       5.44275       3.33717     12
# 4                0.22055       1.62509       4.13560       2.08071     12
# 133              0.21827       2.00873      10.97214       4.43848     12
# 3                0.21721       1.86066       5.21906       3.74411     12
# 97               0.20828       3.37959       6.78960       2.00861     12
# 49               0.20310       4.58799       7.38045       2.26169     12
#
#       timestamp  checkpoint_dir_name  ...  training_iteration     trial_id  \
# 106  1746154949                  NaN  ...                  12  4906f_00130
# 111  1746148289                  NaN  ...                  12  4906f_00086
# 82   1746153706                  NaN  ...                  12  4906f_00122
# 1    1746153013                  NaN  ...                  12  4906f_00116
# 76   1746140510                  NaN  ...                  12  4906f_00034
# 74   1746154174                  NaN  ...                  12  4906f_00124
# 33   1746151793                  NaN  ...                  12  4906f_00109
# 103  1746145133                  NaN  ...                  12  4906f_00065
# 138  1746156741                  NaN  ...                  12  4906f_00141
# 35   1746141178                  NaN  ...                  12  4906f_00038
# 4    1746144465                  NaN  ...                  12  4906f_00060
# 133  1746150547                  NaN  ...                  12  4906f_00100
# 3    1746149216                  NaN  ...                  12  4906f_00092
# 97   1746143303                  NaN  ...                  12  4906f_00053
# 49   1746147051                  NaN  ...                  12  4906f_00078
#
#                     date time_this_iter_s  time_total_s     pid   hostname  \
# 106  2025-05-02_03-02-29        43.421051    668.145051  764922  frapai16p
# 111  2025-05-02_01-11-29        51.390901    656.227510  691928  frapai16p
# 82   2025-05-02_02-41-46        42.332893    657.691555  751435  frapai16p
# 1    2025-05-02_02-30-13        50.711266    653.189938  743644  frapai16p
# 76   2025-05-01_23-01-50        57.099519    678.383016  607022  frapai16p
# 74   2025-05-02_02-49-34        56.912276    664.299406  756036  frapai16p
# 33   2025-05-02_02-09-53        55.254729    669.081054  730246  frapai16p
# 103  2025-05-02_00-18-53        41.684110    660.882204  657511  frapai16p
# 138  2025-05-02_03-32-21        47.250102    657.967643  784076  frapai16p
# 35   2025-05-01_23-12-58        55.660000    661.952633  614342  frapai16p
# 4    2025-05-02_00-07-45        56.174193    653.336713  650047  frapai16p
# 133  2025-05-02_01-49-07        57.077809    658.335137  716476  frapai16p
# 3    2025-05-02_01-26-56        57.246365    658.759950  702509  frapai16p
# 97   2025-05-01_23-48-23        56.894238    665.855150  637826  frapai16p
# 49   2025-05-02_00-50-51        51.488249    656.814321  678800  frapai16p
#
#            node_ip time_since_restore  iterations_since_restore
# 106  192.168.16.12         668.145051                        12
# 111  192.168.16.12         656.227510                        12
# 82   192.168.16.12         657.691555                        12
# 1    192.168.16.12         653.189938                        12
# 76   192.168.16.12         678.383016                        12
# 74   192.168.16.12         664.299406                        12
# 33   192.168.16.12         669.081054                        12
# 103  192.168.16.12         660.882204                        12
# 138  192.168.16.12         657.967643                        12
# 35   192.168.16.12         661.952633                        12
# 4    192.168.16.12         653.336713                        12
# 133  192.168.16.12         658.335137                        12
# 3    192.168.16.12         658.759950                        12
# 97   192.168.16.12         665.855150                        12
# 49   192.168.16.12         656.814321                        12
#
# [15 rows x 21 columns]

# %%
import numpy as np

# Define the metrics and their ranking order (True for ascending, False for descending)
metrics_for_rrf = {
    "metrics/mAP50-95(B)": False,
    "metrics/mAP50(B)": False,
    "val/box_loss": True,
    "val/cls_loss": True,
    "val/dfl_loss": True,
}

# Constant k for RRF calculation
k = 60  # A common value, you can experiment with this

# Calculate ranks for each metric
for metric, ascending_order in metrics_for_rrf.items():
    rank_col_name = f"{metric}_rank"
    filtered_data[rank_col_name] = filtered_data[metric].rank(method='min', ascending=ascending_order)

# Calculate RRF score
rrf_score_col = 'rrf_score'
filtered_data[rrf_score_col] = 0
for metric in metrics_for_rrf:
    rank_col_name = f"{metric}_rank"
    filtered_data[rrf_score_col] += 1 / (k + filtered_data[rank_col_name])

# Sort by RRF score to find the best trials
top_trials_rrf = filtered_data.sort_values(by=rrf_score_col, ascending=False)

# Display the top 15 trials based on RRF
print("Top 15 trials based on RRF score:")
display(top_trials_rrf[[col for col in top_trials_rrf.columns if '_rank' not in col]].head(15))

# You can now use top_trials_rrf['trial_id'].head(15) for further steps
# like identifying the folders to keep.
# Out:
# Top 15 trials based on RRF score:
#      metrics/precision(B)  metrics/recall(B)  metrics/mAP50(B)  \
# 4                 0.62322            0.37530           0.39805
# 1                 0.65474            0.48990           0.54699
# 44                0.58253            0.31092           0.35583
# 35                0.48080            0.42241           0.41864
# 33                0.68591            0.41288           0.44390
# 106               0.79764            0.48442           0.59333
# 117               0.43997            0.40387           0.36943
# 138               0.59751            0.42737           0.46584
# 76                0.62881            0.44398           0.42962
# 111               0.81120            0.45739           0.58416
# 3                 0.65581            0.41929           0.39914
# 146               0.35580            0.50140           0.34979
# 31                0.43153            0.29767           0.29868
# 15                0.41211            0.42138           0.36194
# 82                0.54076            0.46651           0.49341
#
#      metrics/mAP50-95(B)  val/box_loss  val/cls_loss  val/dfl_loss  epoch  \
# 4                0.22055       1.62509       4.13560       2.08071     12
# 1                0.27292       2.22462      12.05279       0.97501     12
# 44               0.16982       2.02036       2.58868       1.17233     12
# 35               0.22603       1.24219       5.44275       3.33717     12
# 33               0.25484       2.14887       8.02815       1.70921     12
# 106              0.37920       3.24221      10.72639       1.68175     12
# 117              0.18089       2.45450       3.21190       2.21732     12
# 138              0.23621       1.73008       7.84999       3.69570     12
# 76               0.27094       2.25988       6.37747       3.30324     12
# 111              0.33471       2.45463       7.83894       3.39335     12
# 3                0.21721       1.86066       5.21906       3.74411     12
# 146              0.19277       2.53836       3.06390       2.81249     12
# 31               0.15890       1.48866       3.73693       3.30407     12
# 15               0.18573       1.57029      10.87521       2.64928     12
# 82               0.30038       3.35695       7.66204       3.11183     12
#
#       timestamp  checkpoint_dir_name  ...     trial_id                 date  \
# 4    1746144465                  NaN  ...  4906f_00060  2025-05-02_00-07-45
# 1    1746153013                  NaN  ...  4906f_00116  2025-05-02_02-30-13
# 44   1746157639                  NaN  ...  4906f_00148  2025-05-02_03-47-19
# 35   1746141178                  NaN  ...  4906f_00038  2025-05-01_23-12-58
# 33   1746151793                  NaN  ...  4906f_00109  2025-05-02_02-09-53
# 106  1746154949                  NaN  ...  4906f_00130  2025-05-02_03-02-29
# 117  1746154296                  NaN  ...  4906f_00125  2025-05-02_02-51-36
# 138  1746156741                  NaN  ...  4906f_00141  2025-05-02_03-32-21
# 76   1746140510                  NaN  ...  4906f_00034  2025-05-01_23-01-50
# 111  1746148289                  NaN  ...  4906f_00086  2025-05-02_01-11-29
# 3    1746149216                  NaN  ...  4906f_00092  2025-05-02_01-26-56
# 146  1746138011                  NaN  ...  4906f_00018  2025-05-01_22-20-11
# 31   1746151786                  NaN  ...  4906f_00108  2025-05-02_02-09-46
# 15   1746142074                  NaN  ...  4906f_00045  2025-05-01_23-27-54
# 82   1746153706                  NaN  ...  4906f_00122  2025-05-02_02-41-46
#
#     time_this_iter_s time_total_s     pid   hostname        node_ip  \
# 4          56.174193   653.336713  650047  frapai16p  192.168.16.12
# 1          50.711266   653.189938  743644  frapai16p  192.168.16.12
# 44         29.945347   455.324486  795757  frapai16p  192.168.16.12
# 35         55.660000   661.952633  614342  frapai16p  192.168.16.12
# 33         55.254729   669.081054  730246  frapai16p  192.168.16.12
# 106        43.421051   668.145051  764922  frapai16p  192.168.16.12
# 117        38.980478   647.043162  757495  frapai16p  192.168.16.12
# 138        47.250102   657.967643  784076  frapai16p  192.168.16.12
# 76         57.099519   678.383016  607022  frapai16p  192.168.16.12
# 111        51.390901   656.227510  691928  frapai16p  192.168.16.12
# 3          57.246365   658.759950  702509  frapai16p  192.168.16.12
# 146        51.253746   661.057224  579775  frapai16p  192.168.16.12
# 31         57.339337   672.695245  729874  frapai16p  192.168.16.12
# 15         56.909899   667.876015  624525  frapai16p  192.168.16.12
# 82         42.332893   657.691555  751435  frapai16p  192.168.16.12
#
#     time_since_restore iterations_since_restore  rrf_score
# 4           653.336713                       12   0.066553
# 1           653.189938                       12   0.065422
# 44          455.324486                       12   0.065324
# 35          661.952633                       12   0.062994
# 33          669.081054                       12   0.061240
# 106         668.145051                       12   0.060174
# 117         647.043162                       12   0.058615
# 138         657.967643                       12   0.058468
# 76          678.383016                       12   0.058141
# 111         656.227510                       12   0.058000
# 3           658.759950                       12   0.057631
# 146         661.057224                       12   0.056852
# 31          672.695245                       12   0.056274
# 15          667.876015                       12   0.055343
# 82          657.691555                       12   0.055277
#
# [15 rows x 22 columns]

# %%
folders = glob("zindi_challenge_cacao_tune/tuning_run/_tune*")
len(folders)
# Out:
# 150

# %%
folders[0]
# Out:
# 'zindi_challenge_cacao_tune/tuning_run/_tune_4906f_00088'

# %%
top_trials_rrf["trial_id"].head(15)
# Out:
# 4      4906f_00060
# 1      4906f_00116
# 44     4906f_00148
# 35     4906f_00038
# 33     4906f_00109
# 106    4906f_00130
# 117    4906f_00125
# 138    4906f_00141
# 76     4906f_00034
# 111    4906f_00086
# 3      4906f_00092
# 146    4906f_00018
# 31     4906f_00108
# 15     4906f_00045
# 82     4906f_00122
# Name: trial_id, dtype: object

# %%
id2folder = {}
for folder in folders:
	trial_id = folder.split("/")[-1].replace("_tune_", "")
	id2folder[trial_id] = folder

len(id2folder)
# Out:
# 150

# %%
id2folder["4906f_00000"]
# Out:
# 'zindi_challenge_cacao_tune/tuning_run/_tune_4906f_00000'

# %%
for trial_id in top_trials_rrf["trial_id"].head(20):
	folder = id2folder[trial_id]
	del id2folder[trial_id]

len(id2folder)
# Out:
# 130

# %%
import shutil

for folder in tqdm(id2folder.values()):
	try:
		shutil.rmtree(folder)
	except Exception as e:
		print(f"Error deleting {folder}: {e}")
# Out:
#   0%|          | 0/130 [00:00<?, ?it/s]
# 100%|██████████| 130/130 [00:00<00:00, 503.44it/s]
